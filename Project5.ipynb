# %% [markdown]
# <a href="https://colab.research.google.com/github/dkaiser7/Discrete_Math/blob/master/Project5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #5 : CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Structures
# ### Darcie Kaiser 266940

# %% [markdown]
# ## 1 Graphs and Trees

# %% [markdown]
# For this project, I am going to use the places I have gone to since senior of high school to now. So 2018-2022. These will include me going back home during the summer to live while I am on break from college.

# %%
import graphviz

dot = graphviz.Digraph(comment='Traveling')
dot.node('E', 'Eaton')
dot.node('W', 'Sheridan, Wyoming')
dot.node('C', 'East Central')

dot.edges(['EW', 'WE','EW', 'WE', 'EC', 'CE', 'EC'])
dot.edge('W', 'C', constraint='false')
dot.edge('E','W')
dot

# %% [markdown]
# This is just showing where I was bouncing two and from like summer breaks to the start of new years at my different schools. As you can see, the last school shown in path is East Central which is where I will be graduating.

# %% [markdown]
# **Path**
#
# The path in this structure using the letters I assigned in this is
# $$EW, WE, EW, WE, EC, CE, EC$$
# The path is just showing where I went to and from each new year and each summer since I lived in each place.

# %% [markdown]
# The biggest degree of vertect would be $E$ which is Eaton. And the degree is atleast 5.

# %% [markdown]
# The cycle that exists is that Freshman year of college I went to $W$, Wyoming, and then for summer I went back to live in Eaton, $E$. Sophomore year, I went back to Wyoming and then back to Eaton. Then, Junior I went from Eaton in summer break to East Central, $E$. And then back to Eaton for summer break. Eaton, $E$, is repeated qquite a bit and so that is the path.

# %% [markdown]
# WHat I found in this project is a really cool looking tree is where I have been going and coming back from each year after high school.

# %% [markdown]
# I went to a junior college for two years ot play volleyball up in wyoming before I came to East Central. So going back and forth from places has been a huge adventure for me the last couple years.
